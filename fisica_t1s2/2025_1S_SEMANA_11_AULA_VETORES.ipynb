# %% [markdown]
# <img src= "https://maua.br/images/logo-IMT.png" width=250>

# %% [markdown]
# #  <center> <font color=#023e8a>  **CIC202: Física e Modelagem Computacional**  <center>
#  <center> Prof. Sandro Martini <center>

# %% [markdown]
# # <center>  **Semana 11: Operações com Vetores no Python**

# %% [markdown]
# ### Nome: não esqueça de colocar seu nome aqui

# %% [markdown]
# ### Instruções iniciais:
#
# 1. Coloque todos os arquivos que você baixou num mesmo diretório;
# 2. **Leia o notebook** e realize as tarefas indicadas;
# 4. Quando tiver terminado, envie esse próprio arquivo com as atividades realizadas.
# 5. Cada aluno deve enviar a sua atividade;
# 6. O laboratório é um momento de independência para que você possa aprender de forma autônoma. Por isso leia atentamente as instruções, discuta com os colegas os exercícios, os códigos e as soluções.

# %% [markdown]
# ### Objetivos:

# %% [markdown]
# -  Compreender as representações e operações vetoriais.
# -  Aprender como representar vetores na linguagem Python.
# -  Resolver exercícios de vetores com Python.

# %% [markdown]
# ### Vetores

# %% [markdown]
# Os vetores são frequentemente usados em matemática, física, engenharia, computação gráfica e outras áreas para representar grandezas que possuem magnitude,  direção e sentido. Eles são úteis para descrever movimento, forças, campos, entre outras grandezas.
#
# Em matemática, um vetor é formalmente definido como um elemento de um espaço vetorial. O espaço vetorial comumente encontrado é o espaço euclidiano. Para qualquer inteiro não-negativo $n$,  o espaço de todos as $n$-uplas de números reais forma um espaço vetorial  $n$-dimensional sobre $\mathbb{R}$ , que é denotado $\mathbb{R}^n$ e às vezes chamado de espaço coordenado real. Algumas vezes os vetores são caracterizados pelo número de coordenadas que eles possuem. Um vetor bidimensional é um vetor que possui duas coordenadas, e um vetor tridimensional é um vetor que possui três coordenadas. De forma geral, um vetor $n$-dimensional é um vetor que possui $n$ coordenadas. A Figura abaixo mostra a representação geométrica de um vetor $\vec{A}$. O ponto $O$ é a origem do vetor e o ponto $E$ é chamado de extremidade do vetor.

# %% [markdown]
# <img src= "2024_1S_SEMANA_05_AULA_VETORES_FIG_01.png" width=350>

# %% [markdown]
# Além da representação geométrica (ou gráfica) utilizada anteriormente (Figura acima), podemos fazer uso de uma outra representação, conhecida como representação analítica do vetor. Na representação analítica utilizamos as componentes do vetor. Para a definir de componentes, a melhor alternativa - e a mais fácil -  é usar um conjunto coordenadas cartesianas. Dado um sistema de coordenadas cartesianas (composto de um conjunto de três eixos ortogonais), podemos definir as componentes de um vetor nesse sistema de eixos tomando-se as projeções do vetor nesses eixos.

# %% [markdown]
# <img src= "2024_1S_SEMANA_05_AULA_VETORES_FIG_02.png" width=550>

# %% [markdown]
# O vetor $\vec{A}$ é então escrito em termos das componentes $A_x$, $A_y$ e $A_z$:
#
# $$\vec{A} = A_{x}\hat{i} + A_{y}\hat{j} + A_{z}\hat{j}$$
#
# Os vetores $\hat{i}$, $\hat{j}$ e $\hat{k}$ são chamados de vetores unitários (versor) ou vetores base e são frequentemente usados para descrever vetores tridimensionais no espaço euclidiano tridimensional (também conhecido como espaço 3D). Esses vetores são definidos como:
#
# $\hat{i}$: vetor unitário na direção $x$, com módulo 1 e coordenadas (1, 0, 0);
#
# $\hat{j}$: vetor unitário na direção $y$, com módulo 1 e coordenadas (0, 1, 0);
#
# $\hat{k}$: vetor unitário na direção $z$, com módulo 1 e coordenadas (0, 0, 1).
#
#
# Esses vetores unitários são perpendiculares entre si e formam um sistema de coordenadas cartesianas no espaço 3D. Qualquer vetor no espaço 3D pode ser expresso como uma combinação linear desses vetores unitários, multiplicados por suas respectivas coordenadas.

# %% [markdown]
# ### Vetores no Python

# %% [markdown]
# Em programação, vetores são comumente utilizados para representar pontos em um espaço bidimensional ou tridimensional, velocidades, forças, entre outras grandezas físicas. Para criar um vetor, podemos usar um `array` em Python. Por exemplo, o vetor $\vec{A} = 3\hat{i} + 4\hat{j}$, cujas coordenadas são $(3,4)$, pode ser criado da seguinte forma:

# %%
A = [3, 4]

# %% [markdown]
# ### Operações com vetores

# %% [markdown]
# Existem diversas operações que podem ser realizadas com vetores, como soma, subtração, multiplicação por escalar, produto escalar e produto vetorial. Aqui vamos inicialmente nos ater as operações de soma e substração.

# %% [markdown]
# A soma de vetores pode ser facilmente implementada em Python. Vamos supor que desejamos o vetor soma $\vec{S} = \vec{A}+\vec{B} $, sendo o vetor $\vec{A} = 3\hat{i} + 4\hat{j}$ e o vetor $\vec{B} = \hat{i} + 2\hat{j}$:

# %%
A = [3,4] #componentes Ax e Ay, respectivamente.
B = [1,2] #componentes Bx e By, respectivamente.
S = [A[0] + B[0], A[1] + B[1]] #Sx = Ax + Bx; Sy = Ay +By
print('Vetor Soma =', S)
# Out:
# Vetor Soma = [4, 6]

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 1:</strong>
#
# Dados os seguintes vetores:
#
# $$\vec{a} = 4,2 \hat{i} - 1,5 \hat{j}$$
# $$\vec{b} = -1,6 \hat{i} + 2,0 \hat{j}$$
#
# Desenvolva um código para obter o vetor soma. O código deve forncer o resultado.
# </div>

# %%
#Coloque aqui seu código
A = [4.2, -1.5]
B = [-1.6, 2.0]
S = [A[0] + B[0], A[1] + B[1]]
print('Vetor Soma =', S)
# Out:
# Vetor Soma = [2.6, 0.5]

# %% [markdown]
# <div class= "alert alert-info">
#
# Acabamos de ver que as operações com vetores em Python são feitas por meio de arrays. Esses arrays podem ser criados com as listas padrão do Python, mas é altamente recomendado utilizar bibliotecas como o `numpy` que possuem funções otimizadas para operações vetoriais. A biblioteca `numpy` oferece uma forma mais eficiente de trabalhar com vetores, permitindo operações mais rápidas e diretas. Vamos supor que desejamos o vetor soma $\vec{S} = \vec{A}+\vec{B} $, sendo o vetor $\vec{A} = 3\hat{i} + 4\hat{j}$ e o vetor $\vec{B} = \hat{i} + 2\hat{j}$:
# </div>

# %%
import numpy as np
A = np.array([3,4])
B = np.array ([1,2])
S = A + B
print('Vetor Soma =', S)

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 2:</strong>
#
# Dados os seguintes vetores:
#
# $$\vec{p} = -7 \hat{i} + 2 \hat{j} -3 \hat{k}$$
# $$\vec{q} = 2 \hat{i} -  \hat{j} + 4 \hat{k}$$
# $$\vec{r} = 2 \hat{i} - 3 \hat{j} + 2 \hat{k}$$
#
# Desenvolva um código para obter o vetor soma utilizando a bilioteca `numpy` e o módulo do vetor soma.  O código deve forncer o ambos os resultados.
# </div>

# %%
#Coloque aqui seu código
import numpy as np

P = np.array([-7, 2, -3])
Q = np.array([2, -1, 4])
R = np.array([2, -3, 2])
S = P + Q + R
print('Vetor Soma c/ numpy =', S)
# Out:
# Vetor Soma c/ numpy = [-3 -2  3]

# %% [markdown]
# ### Representação geométrica de vetores 2D

# %% [markdown]
# Para representar geometricamente um vetor, podemos utilizar a biblioteca `matplotlib`. Para isso, precisamos importar a biblioteca e utilizar a função [quiver](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.quiver.html). Vejamos os argumentos dessa função para representar geometricamente (plotar) o vetor $\vec{v} = 3\hat{i} + 4\hat{j}$. Vejamos algumas linhas do código:
#
# `v = np.array([3, 4])`: escreve o vetor $\vec{v} = 3\hat{i} + 4\hat{j}$
#
# `plt.quiver(0,0,v[0],v[1])`:
#
#    `0 e 0` - Esses são os valores das coordenadas $x$ e $y$ do ponto de partida da seta do vetor. No caso, estamos iniciando a seta do vetor a  partir da origem do sistema de coordenadas, que tem as coordenadas (0, 0).
#
#    `v[0] e v[1]` - Esses são os valores das componentes $x$ e $y$ do vetor. No caso, estamos utilizando os valores armazenados no `array v`.
#
# Dessa forma, a função `quiver` plotará a extremidade do vetor na posição especificada pelas coordenadas `(0, 0)`, a origem do sistema de coordenadas. A seta do vetor será plotada na cor padrão da biblioteca matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

v = np.array([3, 4])

plt.quiver(0,0,v[0],v[1])
plt.grid()
plt.show()

# %% [markdown]
# Entretanto podemos melhorar a representação do vetor utilizando alguns argumentos a mais na função `quiver`. Para isso adicionamos os seguintes argumentos:
#
# `plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1)`
#
# `angles='xy'`: Esse argumento especifica que os ângulos do vetor devem ser medidos em relação ao sistema de coordenadas, em que os eixos x e y são horizontais e verticais, respectivamente.
#
# `scale_units='xy'`:  Esse argumento especifica que a escala do vetor deve ser definida em relação ao sistema de coordenadas, ou seja, um valor de 1 na escala representa a distância de uma unidade no sistema de coordenadas.
#
# `scale=1 `: Esse argumento especifica o fator de escala do vetor. No caso, estamos utilizando o valor 1 para manter o tamanho original do vetor.

# %%
import matplotlib.pyplot as plt

v = np.array([3, 4])

plt.quiver(0, 0, v[0], v[1], angles='xy', scale_units='xy', scale=1)
plt.xlim(-5,5) #define os limites do eixo x do gráfico
plt.ylim(-5,5) #define os limites do eixo y do gráfico
plt.xlabel('Eixo X') #define o rótulo do eixo x de um gráfico
plt.ylabel('Eixo Y') #define o rótulo do eixo x de um gráfico
plt.grid() #adicionar uma grade (ou "grid") ao fundo de um gráfico
plt.show()

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 3:</strong>
#
# Dados os seguintes vetores:
#
# $$\vec{p} = -7 \hat{i} + 2 \hat{j}$$
# $$\vec{q} = 4 \hat{i} -  \hat{j} $$
# $$\vec{r} = 2 \hat{i} - 5 \hat{j}$$
#
# Desenvolva um código para representar os três vetores geometricamente. Todos os vetores devem ter suas origens na origem do sistema.
#
# </div>

# %%
#Coloque aqui seu código
import numpy as np
import matplotlib.pyplot as plt

p = np.array([-7, 2])
q = np.array([4, -1])
r = np.array([2, -5])

plt.quiver(0, 0, p[0], p[1], angles='xy', scale_units='xy', scale=1, color='green')
plt.quiver(0, 0, q[0], q[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(0, 0, r[0], r[1], angles='xy', scale_units='xy', scale=1, color='blue')
plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.grid()
plt.show()

# %% [markdown]
# Ainda é possível adicionar outros argumentos a função `quiver` para alterar as cores dos vetores e criar um rótulo para cada vetor da operação. Veja um exemplo no código abaixo:

# %%
import numpy as np
import matplotlib.pyplot as plt

v1 = np.array([1, 4])
v2 = np.array([1, 2])
soma = v1 + v2

plt.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vetor 1')
plt.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='red', label='Vetor 2')
plt.quiver(0, 0, soma[0], soma[1], angles='xy', scale_units='xy', scale=1, color='green', label='Vetor Soma')
plt.xlim(0, 3)
plt.ylim(0, 7)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 4:</strong>
#
# Considere os seguintes vetores:
#
# $$\vec{v} = 2 \hat{i} + 4 \hat{j}$$
# $$\vec{u} = - \hat{i} + 3  \hat{j} $$
# $$\vec{w} = 3 \hat{i} - 2 \hat{j}$$
#
# Desenvolva um código para representar os três vetores geometricamente e para representar o resultado da operação $\vec{v} - \vec{u} - \vec{w}$.
#
# <strong>OBS</strong>:
#
# 1. Todos os vetores devem ter suas origens na origem do sistema.
# 2. Todos os vetores precisam estar identificados com rótulos e cores.
# 3. Apresente os vetores como uma escala adequada de forma que todos possam ser observados.
#
# </div>

# %%
#Coloque aqui seu código
import numpy as np
import matplotlib.pyplot as plt

p = np.array([2, 4])
q = np.array([-1, 3])
r = np.array([3, -2])

plt.quiver(0, 0, p[0], p[1], angles='xy', scale_units='xy', scale=1, label='Vetor v', color='green')
plt.quiver(0, 0, q[0], q[1], angles='xy', scale_units='xy', scale=1, label='Vetor u', color='red')
plt.quiver(0, 0, r[0], r[1], angles='xy', scale_units='xy', scale=1, label='Vetor w', color='blue')
plt.xlim(-2, 4)
plt.ylim(-3, 5)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Representação geométrica de vetores 3D

# %% [markdown]
# Para representar geométricamente um vetor 3D, importamos o módulo `mpl_toolkits.mplot3d` da biblioteca do `Matplotlib`. Esse módulo permite a criação de gráficos 3D em Python. O módulo fornece uma classe chamada de `Axes3D` que permite a criação de objetos de eixos 3D. O módulo é importado como: `from mpl_toolkits.mplot3d import Axes3D`. Para mais informações sobre esse módulo consulte [3D graphs with Matplotlib](https://pythonprogramming.net/3d-graphs-matplotlib-tutorial/) e [The mplot3d toolkit](https://matplotlib.org/stable/tutorials/toolkits/mplot3d.html).

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure() #Cria uma nova figura vazia na qual podemos adicionar gráficos.

ax = fig.add_subplot(111, projection='3d') #Adiciona um objeto de eixos 3D à figura criada anteriormente ("fig").
#add_subplot: colocamos para adicionar um conjunto de eixos.
#Os argumentos especificam  a localização do eixo e o tipo de plot

v1 = np.array([-1, -3, 5])  # vetor tridimensional

ax.quiver(0, 0, 0, v1[0], v1[1], v1[2], color='blue')
ax.set_xlim([-6, 6])
ax.set_ylim([0, 6])
ax.set_zlim([0, 6])
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_zlabel('Eixo Z')

plt.show()

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 5:</strong>
#
#
# Considere os seguintes vetores:
#
# $$\vec{v} =  \hat{i} + 2 \hat{j} + 3 \hat{k}$$
# $$\vec{u} = -2 \hat{i} +   \hat{j} + 4 \hat{k} $$
# $$\vec{w} = 3 \hat{i} - 2 \hat{j}$$
#
# Desenvolva um código para representar os três vetores geometricamente e para representar o resultado da operação $\vec{v} + \vec{u} - \vec{w}$. O código também deve fornecer o módulo da operação.
#
# <strong>OBS</strong>:
#
# 1. Todos os vetores devem ter suas origens na origem do sistema.
# 2. Utilize cores para cada vetor.
# 3. Apresente os vetores como uma escala adequada de forma que todos possam ser observados.
# </div>

# %%
#Coloque aqui seu código
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

v = np.array([1, 2, 3])
u = np.array([-2, 1, 4])
w = np.array([3, -2, 0])

ax.quiver = (0, 0, 0, v[0], v[1], v[2])
ax.quiver = (0, 0, 0, u[0], u[1], u[2])
ax.quiver = (0, 0, 0, w[0], w[1], w[2])

ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])
ax.set_zlim([-5, 5])
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_zlabel('Eixo Z')

plt.show()

# %% [markdown]
# <div class="alert alert-danger"> <strong> &#x1F4DD; Atividade 6:</strong>
#
#
# Em $t = 0 s$, uma partícula está se movendo no plano xy com uma aceleração constante e com uma velocidade inicial $\vec{v_i} = (3\hat{i} -2\hat{j})$ (m/s) na origem do sistema de coordenadas. Em $t = 3 s$, a velocidade da partícula é $\vec{v} = (9\hat{i} + 7 \hat{j})$ (m/s).
#
# Desenvolva um código para:
#
# (a) representar os vetores velocidades dados;
#
# (b) determinar e representar o vetor aceleração média no intervalo entre $t = 0 s$ e $t = 3 s$. O código também deve fornecer o módulo da aceleração.
#
#
# </div>

# %%
#Coloque aqui seu código
import math
import numpy as np
import matplotlib.pyplot as plt

# a)
v0 = np.array([3, -2])
v1 = np.array([9, 7])

plt.quiver(0, 0, v0[0], v0[1], angles='xy', scale_units='xy', scale=1, label='Vetor Velocidade: t = 0s', color='black')
plt.quiver(3, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, label='Vetor Velocidade: t = 3s', color='green')
plt.xlim([-3, 13])
plt.ylim([-3, 13])
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade (m/s)')
plt.legend()
plt.grid()

plt.show()

# b)
Sub = [v0[0] - v1[0], v0[1] - v1[1]]
A = np.array([Sub[0] / 3, Sub[1] / 3])

plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, label='Vetor Aceleração', color='red')
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.xlabel('Tempo (s)')
plt.ylabel('Aceleração (m/s²)')
plt.legend()
plt.grid()

Modulo_A = ((Sub[0] / 3)**2 + (Sub[1] / 3)**2) ** (1/2)
print(f"Módulo do Vetor Aceleração = {Modulo_A:.2f}")
# Out:
# Módulo do Vetor Aceleração = 3.61
